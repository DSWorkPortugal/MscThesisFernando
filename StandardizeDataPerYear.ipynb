# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Ano 20132014

# %%
Ano20132014 = pd.read_csv('Data/DataClean/Ano20132014Encoding.csv', sep=',')

# %%
del Ano20132014['Sentiu que os vídeos da DreamShaper foram úteis para si?']
del Ano20132014['Os exemplos foram úteis para si?']
del Ano20132014['Acha que a ferramenta tem perguntas a mais ou, pelo contrário, gostaria de ter mais perguntas intermédias que ajudam a ir ‘entrando’ nos novos conceitos?']
del Ano20132014['Quais são os seus 3 aspectos preferidos da ferramenta ? Outros']
del Ano20132014['E quais são os 3 aspectos que menos gosta? Outros']
del Ano20132014['Está satisfeito com a ferramenta DreamShaper?Encod']
del Ano20132014['Quanto aprendeu com a DreamShaper?Encod']
del Ano20132014['Quais são os seus 3 aspectos preferidos da ferramenta ? Acesso a recursos externos']
del Ano20132014['E quais são os 3 aspectos que menos gosta? Acesso a recursos externos']

# %%
Ano20132014.loc[Ano20132014['Está satisfeito com a ferramenta DreamShaper?'] == "Response", 'Está satisfeito com a ferramenta DreamShaper?'] = 1

Ano20132014.loc[Ano20132014['Está satisfeito com a ferramenta DreamShaper?'] == "Muito insatisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 1
Ano20132014.loc[Ano20132014['Está satisfeito com a ferramenta DreamShaper?'] == "Insatisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 2
Ano20132014.loc[Ano20132014['Está satisfeito com a ferramenta DreamShaper?'] == "Nem satisfeito nem insatisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 3
Ano20132014.loc[Ano20132014['Está satisfeito com a ferramenta DreamShaper?'] == "Satisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 4
Ano20132014.loc[Ano20132014['Está satisfeito com a ferramenta DreamShaper?'] == "Muito Satisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 5

# %%
Ano20132014.loc[Ano20132014['Quanto aprendeu com a DreamShaper?'] == "Nada", 'Quanto aprendeu com a DreamShaper?'] = 1
Ano20132014.loc[Ano20132014['Quanto aprendeu com a DreamShaper?'] == "Pouco", 'Quanto aprendeu com a DreamShaper?'] = 2
Ano20132014.loc[Ano20132014['Quanto aprendeu com a DreamShaper?'] == "Alguma coisa", 'Quanto aprendeu com a DreamShaper?'] = 3
Ano20132014.loc[Ano20132014['Quanto aprendeu com a DreamShaper?'] == "Bastante", 'Quanto aprendeu com a DreamShaper?'] = 4
Ano20132014.loc[Ano20132014['Quanto aprendeu com a DreamShaper?'] == "Imenso", 'Quanto aprendeu com a DreamShaper?'] = 5

# %%
Ano20132014 = Ano20132014.dropna()
Ano20132014.columns
# Out:
# Index(['Está satisfeito com a ferramenta DreamShaper?',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de Negócios',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Gestão de projectos',
#        'E quais são os 3 aspectos que menos gosta? Aspecto visual',
# ...

# %%
Ano20132014.columns = [
       'Está satisfeito com a ferramenta DreamShaper?',
       'Positivos:Aspecto Visual',
       'Positivos:Navegação na Ferramenta',
       'Positivos:Perguntas',
       'Positivos:Exemplos',
       'Positivos:Vídeos',
       'Positivos:Modelo de Negócios',
       'Positivos:Indicações de Interface',
       'Positivos:Mural de Equipa',
       'Positivos:Gestão de Equipa',
       'Positivos:Gestão de Projectos',
       'Negativos:Aspecto Visual',
       'Negativos:Navegação na Ferramenta',
       'Negativos:Perguntas',
       'Negativos:Exemplos',
       'Negativos:Vídeos',
       'Negativos:Modelo de Negócios',
       'Negativos:Indicações de Interface',
       'Negativos:Mural de Equipa',
       'Negativos:Gestão de Equipa',
       'Negativos:Gestão de Projectos',
       'Quanto aprendeu com a DreamShaper?'
]

# %%
Ano20132014.to_csv(r'Data/ProcessedDataPerYear/Ano20132014.csv', index = False)

# %% [markdown]
# # Ano 20142015

# %%
Ano20142015 = pd.read_csv('Data/DataClean/Ano20142015Encoding.csv', sep=',')

del Ano20142015['Quais são os seus 3 aspectos preferidos da ferramenta ? Outros']
del Ano20142015['E quais são os 3 aspectos que menos gosta? Outros']
del Ano20142015['Está satisfeito com a ferramenta DreamShaper?Encod']
del Ano20142015['Quanto aprendeu com a DreamShaper?Encod']
del Ano20142015['Quais são os seus 3 aspectos preferidos da ferramenta ? Acesso a recursos externos']
del Ano20142015['E quais são os 3 aspectos que menos gosta? Acesso a recursos externos']

# %%
Ano20142015.loc[Ano20142015['Está satisfeito com a ferramenta DreamShaper?'] == "Response", 'Está satisfeito com a ferramenta DreamShaper?'] = 1
Ano20142015.loc[Ano20142015['Está satisfeito com a ferramenta DreamShaper?'] == "Muito insatisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 1
Ano20142015.loc[Ano20142015['Está satisfeito com a ferramenta DreamShaper?'] == "Insatisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 2
Ano20142015.loc[Ano20142015['Está satisfeito com a ferramenta DreamShaper?'] == "Nem satisfeito nem insatisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 3
Ano20142015.loc[Ano20142015['Está satisfeito com a ferramenta DreamShaper?'] == "Satisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 4
Ano20142015.loc[Ano20142015['Está satisfeito com a ferramenta DreamShaper?'] == "Muito Satisfeito", 'Está satisfeito com a ferramenta DreamShaper?'] = 5

# %%
Ano20142015.loc[Ano20142015['Quanto aprendeu com a DreamShaper?'] == "Não aprendi nada", 'Quanto aprendeu com a DreamShaper?'] = 1
Ano20142015.loc[Ano20142015['Quanto aprendeu com a DreamShaper?'] == "Aprendi, mas pouco", 'Quanto aprendeu com a DreamShaper?'] = 2
Ano20142015.loc[Ano20142015['Quanto aprendeu com a DreamShaper?'] == "Aprendi alguma coisa", 'Quanto aprendeu com a DreamShaper?'] = 3
Ano20142015.loc[Ano20142015['Quanto aprendeu com a DreamShaper?'] == "Aprendi bastante", 'Quanto aprendeu com a DreamShaper?'] = 4
Ano20142015.loc[Ano20142015['Quanto aprendeu com a DreamShaper?'] == "Aprendi imenso!", 'Quanto aprendeu com a DreamShaper?'] = 5

# %%
Ano20142015 = Ano20142015.dropna()

# %%
Ano20142015.columns = [
       'Está satisfeito com a ferramenta DreamShaper?',
       'Positivos:Aspecto Visual',
       'Positivos:Navegação na Ferramenta',
       'Positivos:Perguntas',
       'Positivos:Exemplos',
       'Positivos:Vídeos',
       'Positivos:Modelo de Negócios',
       'Positivos:Indicações de Interface',
       'Positivos:Mural de Equipa',
       'Positivos:Gestão de Equipa',
       'Positivos:Gestão de Projectos',
       'Negativos:Aspecto Visual',
       'Negativos:Navegação na Ferramenta',
       'Negativos:Perguntas',
       'Negativos:Exemplos',
       'Negativos:Vídeos',
       'Negativos:Modelo de Negócios',
       'Negativos:Indicações de Interface',
       'Negativos:Mural de Equipa',
       'Negativos:Gestão de Equipa',
       'Negativos:Gestão de Projectos',
       'Quanto aprendeu com a DreamShaper?'
]

# %%
Ano20142015.to_csv(r'Data/ProcessedDataPerYear/Ano20142015.csv', index = False)

# %% [markdown]
# # Ano 20152016

# %%
Ano20152016 = pd.read_csv('Data/DataClean/Ano20152016Encoding.csv', sep=',')
Ano20152016.columns
del Ano20152016['Quais são os seus 3 aspectos preferidos da ferramenta ? Outros']
del Ano20152016['E quais são os 3 aspectos que menos gosta? Outros']
del Ano20152016['Unnamed: 24']
del Ano20152016['Unnamed: 26']
del Ano20152016['Unnamed: 12']
del Ano20152016['Em que etapa do concurso sentiu mais dificuldade?']
del Ano20152016['Quanto aprendeu com a DreamShaper?Encod']

# %%
Ano20152016.loc[Ano20152016['Quanto aprendeu com a DreamShaper?'] == "Nada", 'Quanto aprendeu com a DreamShaper?'] = 1
Ano20152016.loc[Ano20152016['Quanto aprendeu com a DreamShaper?'] == "Pouco", 'Quanto aprendeu com a DreamShaper?'] = 2
Ano20152016.loc[Ano20152016['Quanto aprendeu com a DreamShaper?'] == "Alguma coisa", 'Quanto aprendeu com a DreamShaper?'] = 3
Ano20152016.loc[Ano20152016['Quanto aprendeu com a DreamShaper?'] == "Bastante", 'Quanto aprendeu com a DreamShaper?'] = 4
Ano20152016.loc[Ano20152016['Quanto aprendeu com a DreamShaper?'] == "Imenso", 'Quanto aprendeu com a DreamShaper?'] = 5

Ano20152016.head(10)
# Out:
#    Está satisfeito com a ferramenta DreamShaper?(Classifique de 1 a 4, sendo 1: Nada satisfeito e 4: Muito Satisfeito)  \
# 0                                                3.0
# 1                                                4.0
# 2                                                4.0
# 3                                                3.0
# 4                                                4.0
# 5                                                NaN
# 6                                                4.0
# 7                                                2.0
# 8                                                3.0
# 9                                                3.0
#
#    Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual  \
# 0                                                  1
# 1                                                  1
# 2                                                  0
# 3                                                  1
# ...

# %%
Ano20152016 = Ano20152016.fillna(0)

# %%
Ano20152016.columns
# Out:
# Index(['Está satisfeito com a ferramenta DreamShaper?(Classifique de 1 a 4, sendo 1: Nada satisfeito e 4: Muito Satisfeito)',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de Negócios',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Gestão de projectos',
# ...

# %%
Ano20152016.columns = [
       'Está satisfeito com a ferramenta DreamShaper?',
       'Positivos:Aspecto Visual',
       'Positivos:Navegação na Ferramenta',
       'Positivos:Perguntas',
       'Positivos:Exemplos',
       'Positivos:Vídeos',
       'Positivos:Modelo de Negócios',
       'Positivos:Indicações de Interface',
       'Positivos:Mural de Equipa',
       'Positivos:Gestão de Equipa',
       'Positivos:Gestão de Projectos',
       'Negativos:Aspecto Visual',
       'Negativos:Navegação na Ferramenta',
       'Negativos:Perguntas',
       'Negativos:Exemplos',
       'Negativos:Vídeos',
       'Negativos:Modelo de Negócios',
       'Negativos:Indicações de Interface',
       'Negativos:Mural de Equipa',
       'Negativos:Gestão de Equipa',
       'Negativos:Gestão de Projectos',
       'Quanto aprendeu com a DreamShaper?'
]

# %%
Ano20152016 = Ano20152016.astype(int)
Ano20152016
# Out:
#      Está satisfeito com a ferramenta DreamShaper?  Positivos:Aspecto Visual  \
# 0                                                3                         1
# 1                                                4                         1
# 2                                                4                         0
# 3                                                3                         1
# 4                                                4                         0
# ..                                             ...                       ...
# 275                                              0                         0
# 276                                              2                         0
# 277                                              0                         0
# 278                                              3                         0
# 279                                              3                         1
#
# ...

# %%
Ano20152016.to_csv(r'Data/ProcessedDataPerYear/Ano20152016.csv', index = False)

# %% [markdown]
# # Ano 20162017

# %%
Ano20162017 = pd.read_csv('Data/DataClean/Ano20162017Encoding.csv', sep=',')
del Ano20162017['Quais são os seus 3 aspectos preferidos da ferramenta ? Outros']
del Ano20162017['E quais são os 3 aspectos que menos gosta? Outros']
del Ano20162017['Quanto aprendeu com a DreamShaper?Encod']

# %%
Ano20162017.loc[Ano20162017['Quanto aprendeu com a DreamShaper?'] == "Nada", 'Quanto aprendeu com a DreamShaper?'] = 1
Ano20162017.loc[Ano20162017['Quanto aprendeu com a DreamShaper?'] == "Pouco", 'Quanto aprendeu com a DreamShaper?'] = 2
Ano20162017.loc[Ano20162017['Quanto aprendeu com a DreamShaper?'] == "Alguma coisa", 'Quanto aprendeu com a DreamShaper?'] = 3
Ano20162017.loc[Ano20162017['Quanto aprendeu com a DreamShaper?'] == "Bastante", 'Quanto aprendeu com a DreamShaper?'] = 4
Ano20162017.loc[Ano20162017['Quanto aprendeu com a DreamShaper?'] == "Imenso", 'Quanto aprendeu com a DreamShaper?'] = 5

# %%
Ano20162017.columns = [
       'Está satisfeito com a ferramenta DreamShaper?',
       'Positivos:Aspecto Visual',
       'Positivos:Navegação na Ferramenta',
       'Positivos:Perguntas',
       'Positivos:Exemplos',
       'Positivos:Vídeos',
       'Positivos:Modelo de Negócios',
       'Positivos:Indicações de Interface',
       'Positivos:Mural de Equipa',
       'Positivos:Gestão de Equipa',
       'Positivos:Gestão de Projectos',
       'Negativos:Aspecto Visual',
       'Negativos:Navegação na Ferramenta',
       'Negativos:Perguntas',
       'Negativos:Exemplos',
       'Negativos:Vídeos',
       'Negativos:Modelo de Negócios',
       'Negativos:Indicações de Interface',
       'Negativos:Mural de Equipa',
       'Negativos:Gestão de Equipa',
       'Negativos:Gestão de Projectos',
       'Quanto aprendeu com a DreamShaper?'
]

# %%
Ano20162017.to_csv(r'Data/ProcessedDataPerYear/Ano20162017.csv', index = False)

# %% [markdown]
# # Ano 20172018

# %%
Ano20172018 = pd.read_csv('Data/DataClean/Ano20172018Encoding.csv', sep=',')
del Ano20172018['Quais são os seus 3 aspectos preferidos da ferramenta ? Outros']
del Ano20172018['E quais são os 3 aspectos que menos gosta? Outros']
del Ano20172018['Quanto aprendeu com a DreamShaper?Encod']

# %%
Ano20172018.loc[Ano20172018['Quanto aprendeu com a DreamShaper?'] == "Nada", 'Quanto aprendeu com a DreamShaper?'] = 1
Ano20172018.loc[Ano20172018['Quanto aprendeu com a DreamShaper?'] == "Pouco", 'Quanto aprendeu com a DreamShaper?'] = 2
Ano20172018.loc[Ano20172018['Quanto aprendeu com a DreamShaper?'] == "Alguma coisa", 'Quanto aprendeu com a DreamShaper?'] = 3
Ano20172018.loc[Ano20172018['Quanto aprendeu com a DreamShaper?'] == "Bastante", 'Quanto aprendeu com a DreamShaper?'] = 4
Ano20172018.loc[Ano20172018['Quanto aprendeu com a DreamShaper?'] == "Imenso", 'Quanto aprendeu com a DreamShaper?'] = 5

# %%
Ano20172018.columns
# Out:
# Index(['Está satisfeito com a ferramenta DreamShaper?(Classifique de 1 a 4, sendo 1: Nada satisfeito e 4: Muito Satisfeito)',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de negócios',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
#        'Quais são os seus 3 aspectos preferidos da ferramenta ? Gestão de projectos',
# ...

# %%
Ano20172018.columns = [
       'Está satisfeito com a ferramenta DreamShaper?',
       'Positivos:Aspecto Visual',
       'Positivos:Navegação na Ferramenta',
       'Positivos:Perguntas',
       'Positivos:Exemplos',
       'Positivos:Vídeos',
       'Positivos:Modelo de Negócios',
       'Positivos:Indicações de Interface',
       'Positivos:Mural de Equipa',
       'Positivos:Gestão de Equipa',
       'Positivos:Gestão de Projectos',
       'Negativos:Aspecto Visual',
       'Negativos:Navegação na Ferramenta',
       'Negativos:Perguntas',
       'Negativos:Exemplos',
       'Negativos:Vídeos',
       'Negativos:Modelo de Negócios',
       'Negativos:Indicações de Interface',
       'Negativos:Mural de Equipa',
       'Negativos:Gestão de Equipa',
       'Negativos:Gestão de Projectos',
       'Quanto aprendeu com a DreamShaper?'
]

# %%
Ano20172018.to_csv(r'Data/ProcessedDataPerYear/Ano20172018.csv', index = False)
