# %%
# Imports

#basic data wrangling
import pandas as pd
import numpy as np

# %% [markdown]
# # Import Data

# %%
Ano20132014 = pd.read_csv('Data/DataClean/Ano20132014Encoding.csv', sep=',')

Ano20142015 = pd.read_csv('Data/DataClean/Ano20142015Encoding.csv', sep=',')

Ano20152016 = pd.read_csv('Data/DataClean/Ano20152016Encoding.csv', sep=',')

Ano20162017 = pd.read_csv('Data/DataClean/Ano20162017Encoding.csv', sep=',')

Ano20172018 = pd.read_csv('Data/DataClean/Ano20172018Encoding.csv', sep=',')

# %% [markdown]
# ## Pontos Positivos

# %%
Ano20132014positivos = Ano20132014[['Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de Negócios',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Gestão de projectos']]

Ano20142015positivos = Ano20142015[[   'Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de Negócios',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta? Gestão de projectos']]

Ano20152016positivos = Ano20152016[[ 'Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de Negócios',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Gestão de projectos']]

Ano20162017positivos = Ano20162017[['Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de Negócios',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Gestão de projectos']]

Ano20172018positivos = Ano20172018[[ 'Quais são os seus 3 aspectos preferidos da ferramenta ? Aspecto Visual',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Navegação na Ferramenta',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Perguntas',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Exemplos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Vídeos',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Modelo de negócios',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Indicações de Interface',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Mural de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ?  Gestão de equipa',
       'Quais são os seus 3 aspectos preferidos da ferramenta ? Gestão de projectos']]

# %%
Ano20132014positivos.columns = ['Aspecto Visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de Interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']

Ano20142015positivos.columns = ['Aspecto Visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de Interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']
Ano20152016positivos.columns = ['Aspecto Visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de Interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']
Ano20162017positivos.columns = ['Aspecto Visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de Interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']

Ano20172018positivos.columns = ['Aspecto Visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de Interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']

# %%
#save to csv
Ano20132014positivos.to_csv(r'Data/PositivosNegativosStandardized/Ano20132014positivos.csv', index = False)
Ano20142015positivos.to_csv(r'Data/PositivosNegativosStandardized/Ano20142015positivos.csv', index = False)
Ano20152016positivos.to_csv(r'Data/PositivosNegativosStandardized/Ano20152016positivos.csv', index = False)
Ano20162017positivos.to_csv(r'Data/PositivosNegativosStandardized/Ano20162017positivos.csv', index = False)
Ano20172018positivos.to_csv(r'Data/PositivosNegativosStandardized/Ano20172018positivos.csv', index = False)

# %% [markdown]
# ## Pontos Negativos

# %%
Ano20132014negativos = Ano20132014[[ 'E quais são os 3 aspectos que menos gosta? Aspecto visual',
       'E quais são os 3 aspectos que menos gosta? Navegação na ferramenta',
       'E quais são os 3 aspectos que menos gosta? Perguntas',
       'E quais são os 3 aspectos que menos gosta? Exemplos',
       'E quais são os 3 aspectos que menos gosta? Vídeos',
       'E quais são os 3 aspectos que menos gosta? Modelo de negócios',
       'E quais são os 3 aspectos que menos gosta? Indicações de interface',
       'E quais são os 3 aspectos que menos gosta? Mural de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de projectos']]
Ano20142015negativos = Ano20142015[['E quais são os 3 aspectos que menos gosta? Aspecto visual',
       'E quais são os 3 aspectos que menos gosta? Navegação na ferramenta',
       'E quais são os 3 aspectos que menos gosta? Perguntas',
       'E quais são os 3 aspectos que menos gosta? Exemplos',
       'E quais são os 3 aspectos que menos gosta? Vídeos',
       'E quais são os 3 aspectos que menos gosta? Modelo de negócios',
       'E quais são os 3 aspectos que menos gosta? Indicações de interface',
       'E quais são os 3 aspectos que menos gosta? Mural de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de projectos']]
Ano20152016negativos = Ano20152016[['E quais são os 3 aspectos que menos gosta? Aspecto visual',
       'E quais são os 3 aspectos que menos gosta? Navegação na ferramenta',
       'E quais são os 3 aspectos que menos gosta? Perguntas',
       'E quais são os 3 aspectos que menos gosta? Exemplos',
       'E quais são os 3 aspectos que menos gosta? Vídeos',
       'E quais são os 3 aspectos que menos gosta? Modelo de Negócios',
       'E quais são os 3 aspectos que menos gosta? Indicações de interface',
       'E quais são os 3 aspectos que menos gosta? Mural de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de projectos']]
Ano20162017negativos = Ano20162017[['E quais são os 3 aspectos que menos gosta? Aspecto visual',
       'E quais são os 3 aspectos que menos gosta? Navegação na ferramenta',
       'E quais são os 3 aspectos que menos gosta? Perguntas',
       'E quais são os 3 aspectos que menos gosta? Exemplos',
       'E quais são os 3 aspectos que menos gosta? Vídeos',
       'E quais são os 3 aspectos que menos gosta? Modelo de negócios',
       'E quais são os 3 aspectos que menos gosta? Indicações de interface',
       'E quais são os 3 aspectos que menos gosta? Mural de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de projectos']]
Ano20172018negativos = Ano20172018[[ 'E quais são os 3 aspectos que menos gosta? Aspecto visual',
       'E quais são os 3 aspectos que menos gosta? Navegação na ferramenta',
       'E quais são os 3 aspectos que menos gosta? Perguntas',
       'E quais são os 3 aspectos que menos gosta? Exemplos',
       'E quais são os 3 aspectos que menos gosta? Vídeos',
       'E quais são os 3 aspectos que menos gosta? Modelo de negócios',
       'E quais são os 3 aspectos que menos gosta? Indicações de interface',
       'E quais são os 3 aspectos que menos gosta? Mural de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de equipa',
       'E quais são os 3 aspectos que menos gosta? Gestão de projectos']]

# %%
Ano20132014negativos.columns = ['Aspecto visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']
Ano20142015negativos.columns =['Aspecto visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']
Ano20152016negativos.columns = ['Aspecto visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']
Ano20162017negativos.columns =['Aspecto visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']
Ano20172018negativos.columns =['Aspecto visual',
       'Navegação na Ferramenta',
       'Perguntas',
       'Exemplos',
       'Vídeos',
       'Modelo de Negócios',
       'Indicações de interface',
       'Mural de equipa',
       'Gestão de equipa',
       'Gestão de projectos']

# %%
#save to csv
Ano20132014negativos.to_csv(r'Data/PositivosNegativosStandardized/Ano20132014negativos.csv', index = False)
Ano20142015negativos.to_csv(r'Data/PositivosNegativosStandardized/Ano20142015negativos.csv', index = False)
Ano20152016negativos.to_csv(r'Data/PositivosNegativosStandardized/Ano20152016negativos.csv', index = False)
Ano20162017negativos.to_csv(r'Data/PositivosNegativosStandardized/Ano20162017negativos.csv', index = False)
Ano20172018negativos.to_csv(r'Data/PositivosNegativosStandardized/Ano20172018negativos.csv', index = False)
